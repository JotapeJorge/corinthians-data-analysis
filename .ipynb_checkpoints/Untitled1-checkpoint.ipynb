# %%
import pandas as pd
df = pd.read_csv('Data/campeonato_paulista_1955_1976')
df
# Out:
#           Comp  Temp        Data              Casa  GC  GF              Fora  \
# 0     Paulista  1955  1955-01-10         Palmeiras   5   3         Jabaquara
# 1     Paulista  1955  1955-02-10            Santos   4   1         XV de Jaú
# 2     Paulista  1955  1955-02-10       Corinthians   3   2         São Paulo
# 3     Paulista  1955  1955-02-10         São Bento   2   2           Guarani
# 4     Paulista  1955  1955-02-10       Ponte Preta   5   2           Taubaté
# ...        ...   ...         ...               ...  ..  ..               ...
# 5256  Paulista  1976  1976-08-22           Guarani   0   0       Ponte Preta
# 5257  Paulista  1976  1976-08-22         Palmeiras   2   1       Corinthians
# 5258  Paulista  1976  1976-08-22        Portuguesa   1   1  XV de Piracicaba
# 5259  Paulista  1976  1976-08-22  Ferroviária (SP)   1   0      América (SP)
# 5260  Paulista  1976  1976-08-28  XV de Piracicaba   1   0         São Bento
#
#      Res  PC  PF    J
# 0     VC   3   0    1
# 1     VC   3   0    6
# 2     VC   3   0    2
# 3      E   1   1    4
# 4     VC   3   0    3
# ...   ..  ..  ..  ...
# 5256   E   1   1  217
# 5257  VC   3   0  214
# 5258   E   1   1  216
# 5259  VC   3   0  215
# 5260  VC   3   0  218
#
# [5261 rows x 11 columns]

# %%
teams = ['Corinthians', 'São Paulo', 'Santos', 'Palmeiras']

filt = ((df['Casa'].isin(['Corinthians', 'Palmeiras', 'São Paulo, Santos']))
              & (df['Fora'].isin(['Corinthians', 'Palmeiras', 'São Paulo', 'Santos'])))
classicos = df[filt]

# %%
majestoso
# Out:
#           Comp  Temp        Data         Casa  GC  GF         Fora Res  PC  \
# 2     Paulista  1955  1955-02-10  Corinthians   3   2    São Paulo  VC   3
# 126   Paulista  1955  1955-11-12  Corinthians   1   1    São Paulo   E   1
# 312   Paulista  1956  1956-09-16  Corinthians   4   3    São Paulo  VC   3
# 351   Paulista  1956  1956-10-20    São Paulo   1   1  Corinthians   E   1
# 413   Paulista  1956  1956-12-01  Corinthians   2   2    São Paulo   E   1
# 671   Paulista  1957  1957-08-25  Corinthians   2   1    São Paulo  VC   3
# 802   Paulista  1957  1957-10-20  Corinthians   1   1    São Paulo   E   1
# 1006  Paulista  1957  1957-12-29    São Paulo   3   1  Corinthians  VC   3
# 1191  Paulista  1958  1958-08-13  Corinthians   2   0    São Paulo  VC   3
# 1386  Paulista  1958  1958-11-26  Corinthians   1   1    São Paulo   E   1
# 1626  Paulista  1959  1959-10-03    São Paulo   1   0  Corinthians  VC   3
# 1697  Paulista  1959  1959-11-05    São Paulo   4   0  Corinthians  VC   3
# 1977  Paulista  1960  1960-09-15  Corinthians   3   1    São Paulo  VC   3
# 2091  Paulista  1960  1960-11-23    São Paulo   4   1  Corinthians  VC   3
# 671    0  121
# 802    1  203
# 1006   0  333
# 1191   0  130
# 1386   1  325
# 1626   0  190
# 1697   0  254
# 1977   0  152
# 2091   0  266
# 2156   0   25
# 2309   1  178
# 2443   1   68
# 2583   0  210
# 2681   0   71
# 2805   0  193
# 2909   1   58
# 3021   0  169
# 3113   0   22
# 3232   1  140
# 3401   3   72
# 3518   0  186
# 3590   1   48
# 3718   1  181
# 3797   3   72
# 3840   1  121
# 3939   3   33
# 4059   3  151
# 4075   3  172
# 4122   1   29
# 4183   3   90
# 4221   1   39
# 4289   0  106
# 4332   1   17
# 4414   1   99
# 4480   1   32
# 4571   0  123
# 4671   3   91
# 4741   0  160
# 4823   3   56
# 5040   0  276
# 5061   0   22
# 5241   0  199

# %%
def update_team_stats(df):
    team_stats = {}

    for index, row in df.iterrows():
        home_team, away_team = row['Casa'], row['Fora']
        result = row['Res']

        # Update home team stats
        team_stats.setdefault(home_team, {'Games': 0, 'Victories': 0, 'Losses': 0, 'Draws': 0, 'Goals': 0, 'Points': 0})
        team_stats[home_team]['Games'] += 1
        team_stats[home_team]['Goals'] += row['GC']

        if result == 'VC':
            team_stats[home_team]['Victories'] += 1
            team_stats[home_team]['Points'] += 2
        elif result == 'VV':
            team_stats[home_team]['Losses'] += 1
        else:
            team_stats[home_team]['Draws'] += 1
            team_stats[home_team]['Points'] += 1

        # Update away team stats
        team_stats.setdefault(away_team, {'Games': 0, 'Victories': 0, 'Losses': 0, 'Draws': 0, 'Goals': 0, 'Points': 0})
        team_stats[away_team]['Games'] += 1
        team_stats[away_team]['Goals'] += row['GF']

        if result == 'VC':
            team_stats[away_team]['Losses'] += 1
        elif result == 'VV':
            team_stats[away_team]['Victories'] += 1
            team_stats[away_team]['Points'] += 2
        else:
            team_stats[away_team]['Draws'] += 1
            team_stats[away_team]['Points'] += 1

    # Create a DataFrame with team statistics
    team_stats_df = pd.DataFrame.from_dict(team_stats, orient='index').reset_index()
    team_stats_df = team_stats_df.rename(columns={'index': 'Team'})
    team_stats_df = team_stats_df.sort_values(by='Points', ascending=False)

    # Calculating the percentage of victories, draws, and losses
    team_stats_df['Victory Percentage'] = (team_stats_df['Victories'] / team_stats_df['Games']) * 100
    team_stats_df['Draw Percentage'] = (team_stats_df['Draws'] / team_stats_df['Games']) * 100
    team_stats_df['Loss Percentage'] = (team_stats_df['Losses'] / team_stats_df['Games']) * 100

    # Calculating the percentage of total points based on the maximum possible points
    max_possible_points = team_stats_df['Games'] * 2
    team_stats_df['Points Percentage'] = (team_stats_df['Points'] / max_possible_points) * 100

    return team_stats_df

# Example usage:
derby_stats = update_team_stats(derby)
majestoso_stats = update_team_stats(majestoso)
alvinegro_stats = update_team_stats(alvinegro)
sansao_stats = update_team_stats(sansao)
palxsan_stats = update_team_stats(palxsan)
choque_rei_stats = update_team_stats(choque)

print(derby_stats)
print(majestoso_stats)
print(alvinegro_stats)
print(sansao_stats)
print(palxsan_stats)
print(choque_rei_stats)
# Out:
#           Team  Games  Victories  Losses  Draws  Goals  Points  \
# 0  Corinthians     50         19      15     16     67      54
# 1    Palmeiras     50         15      19     16     68      46
#
#    Victory Percentage  Draw Percentage  Loss Percentage  Points Percentage
# 0                38.0             32.0             30.0               54.0
# 1                30.0             32.0             38.0               46.0
#           Team  Games  Victories  Losses  Draws  Goals  Points  \
# 0  Corinthians     47         17      13     17     62      51
# 1    São Paulo     47         13      17     17     64      43
#
#    Victory Percentage  Draw Percentage  Loss Percentage  Points Percentage
# 0           36.170213        36.170213        27.659574          54.255319
# 1           27.659574        36.170213        36.170213          45.744681
#           Team  Games  Victories  Losses  Draws  Goals  Points  \
# 1       Santos     47         22      10     15    100      59
# 0  Corinthians     47         10      22     15     67      35
#
#    Victory Percentage  Draw Percentage  Loss Percentage  Points Percentage
# 1           46.808511        31.914894        21.276596          62.765957
# 0           21.276596        31.914894        46.808511          37.234043
#         Team  Games  Victories  Losses  Draws  Goals  Points  \
# 0     Santos     49         19      14     16     87      54
# 1  São Paulo     49         14      19     16     75      44
#
#    Victory Percentage  Draw Percentage  Loss Percentage  Points Percentage
# 0           38.775510        32.653061        28.571429          55.102041
# 1           28.571429        32.653061        38.775510          44.897959
#         Team  Games  Victories  Losses  Draws  Goals  Points  \
# 1     Santos     49         21      18     10     81      52
# 0  Palmeiras     49         18      21     10     69      46
#
#    Victory Percentage  Draw Percentage  Loss Percentage  Points Percentage
# 1           42.857143        20.408163        36.734694          53.061224
# 0           36.734694        20.408163        42.857143          46.938776
#         Team  Games  Victories  Losses  Draws  Goals  Points  \
# 1  São Paulo     48         16      15     17     57      49
# 0  Palmeiras     48         15      16     17     51      47
#
#    Victory Percentage  Draw Percentage  Loss Percentage  Points Percentage
# 1           33.333333        35.416667        31.250000          51.041667
# 0           31.250000        35.416667        33.333333          48.958333

# %%
teams = majestoso_stats['Team']
victories = majestoso_stats['Victories']
draws = majestoso_stats['Draws']
losses = majestoso_stats['Losses']

# Plotting a bar chart
fig, ax = plt.subplots(figsize=(10, 6))

bar_width = 0.2
index = range(len(teams))

bar1 = ax.bar(index, victories, bar_width, label='Victories')
bar2 = ax.bar([i + bar_width for i in index], draws, bar_width, label='Draws')
bar3 = ax.bar([i + 2 * bar_width for i in index], losses, bar_width, label='Losses')

# Adding labels, title, and legend
ax.set_xlabel('Teams')
ax.set_ylabel('Number of Games')
ax.set_title('Number of Games by Result')
ax.set_xticks([i + bar_width for i in index])
ax.set_xticklabels(teams, rotation=45, ha='right')
ax.legend()

# Display the plot
plt.tight_layout()
plt.show()
